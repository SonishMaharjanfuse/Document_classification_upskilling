# %%
# %%capture
# !unzip /content/drive/MyDrive/document_classification/model_4_classes/data.zip

# %% [markdown]
# # Install the library

# %%
# !pip install ultralytics

# %% [markdown]
# # Training

# %%
# import YOLO model
from ultralytics import YOLO

# Load a model
model = YOLO('yolov8n-cls.pt')  # load a pretrained model

# Train the model
model.train(data='/content/data', epochs=5)
# Out:
# ...
# 100%|██████████| 5.30M/5.30M [00:00<00:00, 56.5MB/s]
# Ultralytics YOLOv8.1.1 🚀 Python-3.10.12 torch-2.1.0+cu121 CPU (Intel Xeon 2.20GHz)
# ...

# %% [markdown]
# # Save the model

# %%
# Save the model
model.export()
# Out:
# Ultralytics YOLOv8.1.1 🚀 Python-3.10.12 torch-2.1.0+cu121 CPU (Intel Xeon 2.20GHz)
# YOLOv8n-cls summary (fused): 73 layers, 1440004 parameters, 0 gradients, 3.3 GFLOPs
#
# PyTorch: starting from 'runs/classify/train/weights/best.pt' with input shape (1, 3, 224, 224) BCHW and output shape(s) (1, 4) (2.8 MB)
#
# TorchScript: starting export with torch 2.1.0+cu121...
# TorchScript: export success ✅ 0.7s, saved as 'runs/classify/train/weights/best.torchscript' (5.6 MB)
#
# Export complete (2.1s)
# Results saved to /content/runs/classify/train/weights
# Predict:         yolo predict task=classify model=runs/classify/train/weights/best.torchscript imgsz=224
# Validate:        yolo val task=classify model=runs/classify/train/weights/best.torchscript imgsz=224 data=/content/data
# Visualize:       https://netron.app
# 'runs/classify/train/weights/best.torchscript'

# %% [markdown]
# # Evaluate the model

# %%
# Validate the model
metrics = model.val()  # no arguments needed, dataset and settings remembered
metrics.top1  # top1 accuracy
metrics.top5  # top5 accuracy`
# Out:
# Ultralytics YOLOv8.1.1 🚀 Python-3.10.12 torch-2.1.0+cu121 CPU (Intel Xeon 2.20GHz)
# YOLOv8n-cls summary (fused): 73 layers, 1440004 parameters, 0 gradients, 3.3 GFLOPs
# train: /content/data/train... found 3625 images in 4 classes ✅
# val: /content/data/validation... found 1234 images in 4 classes ✅
# test: None...
# val: Scanning /content/data/validation... 1234 images, 0 corrupt: 100%|██████████| 1234/1234 [00:00<?, ?it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 78/78 [00:53<00:00,  1.45it/s]
#                    all      0.985          1
# Speed: 0.0ms preprocess, 13.9ms inference, 0.0ms loss, 0.0ms postprocess per image
# Results saved to runs/classify/train2
# 1.0

# %% [markdown]
# # Inference

# %%
# Load the best model for inference
model2 = YOLO('/content/runs/classify/train/weights/best.pt')

# %%
import numpy as np
from PIL import Image
image_path = "/content/test2.jpeg"
Image.open(image_path)
results = model2.predict(image_path)
name_dic = results[0].names
key = np.argmax(results[0].probs.data).item()
print(f"prediction:{name_dic[key]}")
# Out:
# image 1/1 /content/test2.jpeg: 224x224 citizenship 0.94, others 0.06, passport 0.00, license 0.00, 26.0ms
# Speed: 10.2ms preprocess, 26.0ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
# prediction:citizenship

# %%
Image.open(image_path)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=259x194>
